# %% [markdown]
# 4) La ecuación $x^2 − 2𝑥 − 3 = 0$ tiene dos raíces, en $x = -1 $ y en $x = 3$.
#
# a) Grafique la función $𝑓(𝑥) = 𝑥^2 − 2𝑥 − 3$ en el intervalo: [-4 , 4].

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 100)
y = x**2 - 2*x -3

plt.plot(x,y)

# %% [markdown]
#     b) Se proponen las siguientes funciones de iteración:
#
# $𝑔_1(𝑥) = \sqrt{2𝑥 + 3} $
#
# $𝑔_2(𝑥) = \frac{𝑥^2−3}{2}$
#
# $𝑔_3(𝑥) = \frac{3}{𝑥−2}$
#
# Implemente el método de punto fijo para aproximar las raíces de la función f(x) con cada una de estas funciones, calculando el error en cada iteración.
#
# Utilizando los siguientes valores iniciales:
#
# i) – 4 ii ) -0.99 iii) 3.5 iv) 2 v) 0
#
# - ¿Cómo influye la elección de la función de iteración? Y de los puntos iniciales?
# - Grafique en un mismo eje cartesiano cada función g(x), f(x) y la primera bisectriz. ¿Qué puede observar?

# %%
import numpy as np

x = np.linspace(-4, 4, 100)

def f(x):
    return x**2 - 2*x -3 ##raíces en x=-1, x=3

def g1(x):
    return np.sqrt(2*x+3)

def g2(x):
    return (x**2-3)/2

def g3(x):
    return 3/(x-2)

### Método de punto fijo:
def puntoFijo(a, itmax, eps, g):
    
    it = 0
    error = eps + 1
    
    print("\nIteraciones: ", end="")
    
    while it <= itmax and error > eps:
        it = it + 1
        b = g(a)
        error = np.abs(b-a)
        print('{:<.2e}'.format(error), '  ', end="")
        a = b

    if it > itmax:
        print("\nNo converge")
    else: 
        print("\nLa raíz es:  ", '{:.6f}'.format(b), "\tError: ", error, " N° de iteraciones: ", it)
        
### implementación...
itmax = 20
eps   = 1E-4

print("\n--- g1 ---")
print("\nx = -4")
# puntoFijo(-4, itmax, eps, g1)
print("Raíz de un número negativo.")
print("\nx = -0.99")
puntoFijo(-0.99, itmax, eps, g1)
print("\nx = 3.5")
puntoFijo(3.5, itmax, eps, g1)
print("\nx = 2")
puntoFijo(2, itmax, eps, g1)
print("\nx = 0")
puntoFijo(0, itmax, eps, g1)

print("\n\n--- g2 ---")
print("\nx = -4")
# puntoFijo(-4, itmax, eps, g2) ##OverflowError: (34, 'Result too large')
print("No converge, a-b incrementó exponencialmente")
print("\nx = -0.99")
# puntoFijo(-0.99, itmax, eps, g2)
print("No converge, número de iteraciones agotado.")
print("\nx = 3.5")
# puntoFijo(3.5, itmax, eps, g2) ##OverflowError: (34, 'Result too large')
print("No converge, a-b incrementó exponencialmente.")
print("\nx = 2")
# puntoFijo(2, itmax, eps, g2)
print("No converge, número de iteraciones agotado.")
print("\nx = 0")
# puntoFijo(0, itmax, eps, g2)
print("No converge, número de iteraciones agotado.")

print("\n\n--- g3 ---")
print("\nx = -4")
puntoFijo(-4, itmax, eps, g3)
print("\nx = -0.99")
puntoFijo(-0.99, itmax, eps, g3)
print("\nx = 3.5")
# puntoFijo(3.5, itmax, eps, g3) ##ZeroDivisionError: float division by zero
print("División por cero en la segunda iteración 3/1.5=2 - 2")
print("\nx = 2")
# puntoFijo(2, itmax, eps, g3) ##ZeroDivisionError: division by zero
print("División por cero en la primera iteración 2 - 2")
print("\nx = 0")
puntoFijo(0, itmax, eps, g3)
# Out:
# --- g1 ---
#
# x = -4
# Raíz de un número negativo.
#
# x = -0.99
#
# Iteraciones: 2.00e+00   1.23e+00   4.95e-01   1.75e-01   5.96e-02   2.00e-02   6.68e-03   2.23e-03   7.43e-04   2.48e-04   8.26e-05
# La raíz es:   2.999959 	Error:  8.257786027288105e-05  N° de iteraciones:  11
#
# x = 3.5
#
# Iteraciones: 3.38e-01   1.09e-01   3.58e-02   1.19e-02   3.96e-03   1.32e-03   4.39e-04   1.46e-04   4.88e-05
# La raíz es:   3.000024 	Error:  4.881205199147587e-05  N° de iteraciones:  9
#
# x = 2
#
# Iteraciones: 6.46e-01   2.34e-01   8.01e-02   2.69e-02   9.00e-03   3.00e-03   1.00e-03   3.34e-04   1.11e-04   3.71e-05
# La raíz es:   2.999981 	Error:  3.710743727136645e-05  N° de iteraciones:  10
#
# x = 0
#
# Iteraciones: 1.73e+00   8.10e-01   3.01e-01   1.04e-01   3.51e-02   1.17e-02   3.92e-03   1.31e-03   4.35e-04   1.45e-04   4.84e-05
# La raíz es:   2.999976 	Error:  4.837190459339169e-05  N° de iteraciones:  11
#
#
# --- g2 ---
#
# x = -4
# ...

# %% [markdown]
#     Grafique en un mismo eje cartesiano cada función g(x), f(x) y la primera bisectriz. ¿Qué puede observar?

# %%
x = np.linspace(-4, 4, 100)

y0 = f(x)
y1 = g1(x)
y2 = g2(x)
y3 = g3(x)

plt.figure(1, (15, 5))
plt.subplot(121).title.set_text('g1(x)')
plt.xlim(0,4)
plt.plot(x,x)
plt.plot(x,y1)

plt.subplot(122).title.set_text('g1(x) vs f(x)')
plt.ylim(-4,6)
plt.xlim(-2,4)
plt.plot(x,x)
plt.plot(x,y1)
plt.plot(x,y0)

plt.figure(2, (15, 5))
plt.subplot(121).title.set_text('g2(x)')
plt.ylim(-5,5)
plt.plot(x,x)
plt.plot(x,y2)

plt.subplot(122).title.set_text('g2(x) vs f(x)')
plt.ylim(-4,6)
plt.xlim(-2,4)
plt.plot(x,x)
plt.plot(x,y2)
plt.plot(x,y0)

plt.figure(3, (15, 5))
plt.subplot(121).title.set_text('g3(x)')
plt.ylim(-5,5)
plt.plot(x,x)
plt.plot(x,y3)

plt.subplot(122).title.set_text('g3(x) vs f(x)')
plt.ylim(-4,6)
plt.xlim(-2,4)
plt.plot(x,x)
plt.plot(x,y3)
plt.plot(x,y0)
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_8076/657865090.py:9: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(2*x+3)

# %% [markdown]
# + g1 no es contínua en el intervalo, pero si lo es dentro del intervalo de las raíces de f. Su pendiente es <1
# + g2 tiene un punto de inflexión dentro del intervalo
# + g3 no está definida para x=2

# %% [markdown]
# 5) La función $f(x) = x^2 + x - 1$ tiene una raíz en x = 0.6180339.
#
# a) Proponga 3 funciones de iteración g(x) para estimar esta raíz. Grafique cada una de las funciones de iteración junto a f(x). Analice y escriba con cuál de las funciones propuestas el método va a converger.
#
# Funciones propuestas:
#
# $g_1=\sqrt{1-x}$ -> no converge
#
# $g_2=1-x^2$ -> no converge
#
# $g_3=1/(x+1)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2, 2, 100)
y = x**2 + x -1

y1 = np.sqrt(1-x)
y2 = 1-x**2
y3 = 1/(x+1)

plt.figure(1, (15, 5))
plt.subplot(121).title.set_text('f(x)')
plt.plot(x,y, color="green")

plt.subplot(122).title.set_text('g1(x)')
plt.ylim(0,2)
plt.xlim(0,2)
plt.plot(x,x)
plt.plot(x,y1)
plt.plot(x,y)

plt.figure(2, (15, 5))
plt.subplot(121).title.set_text('g2(x)')
plt.ylim(0,2)
plt.xlim(0,2)
plt.plot(x,x)
plt.plot(x,y2)
plt.plot(x,y)

plt.subplot(122).title.set_text('g3(x)')
plt.ylim(0,2)
plt.xlim(0,2)
plt.plot(x,x)
plt.plot(x,y3)
plt.plot(x,y)
# Out:
# C:\Users\Alumno\AppData\Local\Temp/ipykernel_7908/3327764011.py:7: RuntimeWarning: invalid value encountered in sqrt
#   y1 = np.sqrt(1-x)

# %% [markdown]
# + g1) |g'(x)| es menor a 1 para x<0 . No verifica el teorema. Tiene pendiente negativa. No es contínua en x>1.
# + g2) |g'(x)| es menor a 1 para x<1/2. No verifica el teorema. Tiene pendiente negativa.
# + g3) |g'(x)| < 1 para x>0. Verifica la primera parte del teorema y tiene pendiente negativa. Converge oscilante.

# %% [markdown]
# b) La función de iteración $g_3(x) = \frac{1}{x+1}$ converge a la raíz para $x_0=1$. ¿Cuántas iteraciones del método de punto fijo se requieren para obtener la raíz correcta hasta 3 dígitos? Calcular el error en cada iteración.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2, 100)

def g3(x):
    return 1/(x+1)

print("\ng3) Para x0=1")
puntoFijo(1, 20, 0.01, g3)
# Out:
# g3) Para x0=1
#
# Iteraciones: 5.00e-01   1.67e-01   6.67e-02   2.50e-02   9.62e-03
# La raíz es:   0.615385 	Error:  0.009615384615384581  N° de iteraciones:  5

# %% [markdown]
# c) Programe el método de Steffensen (usando aceleración de Aitken) y repita el cálculo del apartado anterior, ¿cuántas iteraciones se requieren? Calcular los errores cometidos. ¿Qué concluye?

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2, 100)

def g3(x):
    return 1/(x+1)

### Método de punto fijo:
def puntoFijo(a, itmax, eps, g):
    
    it = 0
    error = eps + 1
    
    print("\nIteraciones: ", end="")
    
    while it <= itmax and error > eps:
        it = it + 1
        b = g(a)
        error = np.abs(b-a)
        print('{:<.2e}'.format(error), '  ', end="")
        a = b

    if it > itmax:
        print("\n\nNo converge")
    else: 
        print("\n\nLa raíz es: ", '{:.6f}'.format(b), "\tError: ", error, "\tN° de iteraciones: ", it)

### implementación...
itmax = 20
eps   = 0.001

print("\nx0 = 1")
puntoFijo(1, itmax, eps, g3)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2, 100)

def g3(x):
    return 1/(x+1)

### Método de punto fijo:
def steffensen(a, itmax, eps, g):
    
    it = 0
    error = eps + 1
    
    print("\nIteraciones: ", end="")
    
    while it <= itmax and error > eps:
        it = it + 1
        b = g(a)
        c = g(b)
        error = np.abs(b-a)
        print('{:<.2e}'.format(error), '  ', end="")
        a = a - (a-b)**2 / (c - 2*b + a)

    if it > itmax:
        print("\n\nNo converge")
    else: 
        print("\n\nLa raíz es: ", '{:.6f}'.format(b), "\tError: ", error, "\tN° de iteraciones: ", it)

### implementación...
itmax = 20
eps   = 0.001

print("\nx0 = 1")
steffensen(1, itmax, eps, g3)

# %% [markdown]
# Calcular los errores cometidos. ¿Qué concluye?
# + errores cometidos? mayor número de operaciones?
# + Converge en menos iteraciones
